# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("//home//tabish//Documents//project pyhton data analysis//covid.csv")

# %%
dataset
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     21/12/2021   21     12  2021    1863      20                 Austria
# 1     20/12/2021   20     12  2021    2131      13                 Austria
# 2     19/12/2021   19     12  2021    2378      17                 Austria
# 3     18/12/2021   18     12  2021    2577      51                 Austria
# 4     17/12/2021   17     12  2021    2847      35                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 8875  05/03/2021    5      3  2021    4882      18                  Sweden
# 8876  04/03/2021    4      3  2021    4873      23                  Sweden
# 8877  03/03/2021    3      3  2021    6190      24                  Sweden
# 8878  02/03/2021    2      3  2021    2828      25                  Sweden
# 8879  01/03/2021    1      3  2021  666139   13031                  Sweden
#
#      geoId countryterritoryCode  popData2020 continentExp
# ...

# %%
dataset.shape
# Out:
# (8880, 11)

# %%
dataset.head(20)
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   21/12/2021   21     12  2021   1863      20                 Austria    AT
# 1   20/12/2021   20     12  2021   2131      13                 Austria    AT
# 2   19/12/2021   19     12  2021   2378      17                 Austria    AT
# 3   18/12/2021   18     12  2021   2577      51                 Austria    AT
# 4   17/12/2021   17     12  2021   2847      35                 Austria    AT
# 5   16/12/2021   16     12  2021   3424      54                 Austria    AT
# 6   15/12/2021   15     12  2021   3314      59                 Austria    AT
# 7   14/12/2021   14     12  2021   2829      28                 Austria    AT
# 8   13/12/2021   13     12  2021   3591      19                 Austria    AT
# 9   12/12/2021   12     12  2021   4909      53                 Austria    AT
# 10  11/12/2021   11     12  2021   2512     110                 Austria    AT
# ...

# %%
dataset.tail(20)
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 8860  20/03/2021   20      3  2021    5404      18                  Sweden
# 8861  19/03/2021   19      3  2021    5736      19                  Sweden
# 8862  18/03/2021   18      3  2021    6431      15                  Sweden
# 8863  17/03/2021   17      3  2021    6787      21                  Sweden
# 8864  16/03/2021   16      3  2021    2715      22                  Sweden
# 8865  15/03/2021   15      3  2021    1039      19                  Sweden
# 8866  14/03/2021   14      3  2021    3952      19                  Sweden
# 8867  13/03/2021   13      3  2021    4994      15                  Sweden
# 8868  12/03/2021   12      3  2021    5332      21                  Sweden
# 8869  11/03/2021   11      3  2021    5328      20                  Sweden
# 8870  10/03/2021   10      3  2021    5928      24                  Sweden
# ...

# %%
dataset.head(10)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  21/12/2021   21     12  2021   1863      20                 Austria    AT
# 1  20/12/2021   20     12  2021   2131      13                 Austria    AT
# 2  19/12/2021   19     12  2021   2378      17                 Austria    AT
# 3  18/12/2021   18     12  2021   2577      51                 Austria    AT
# 4  17/12/2021   17     12  2021   2847      35                 Austria    AT
# 5  16/12/2021   16     12  2021   3424      54                 Austria    AT
# 6  15/12/2021   15     12  2021   3314      59                 Austria    AT
# 7  14/12/2021   14     12  2021   2829      28                 Austria    AT
# 8  13/12/2021   13     12  2021   3591      19                 Austria    AT
# 9  12/12/2021   12     12  2021   4909      53                 Austria    AT
#
#   countryterritoryCode  popData2020 continentExp
# 0                  AUT      8901064       Europe
# ...

# %%
dataset.drop('countryterritoryCode', axis=1)
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     21/12/2021   21     12  2021    1863      20                 Austria
# 1     20/12/2021   20     12  2021    2131      13                 Austria
# 2     19/12/2021   19     12  2021    2378      17                 Austria
# 3     18/12/2021   18     12  2021    2577      51                 Austria
# 4     17/12/2021   17     12  2021    2847      35                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 8875  05/03/2021    5      3  2021    4882      18                  Sweden
# 8876  04/03/2021    4      3  2021    4873      23                  Sweden
# 8877  03/03/2021    3      3  2021    6190      24                  Sweden
# 8878  02/03/2021    2      3  2021    2828      25                  Sweden
# 8879  01/03/2021    1      3  2021  666139   13031                  Sweden
#
#      geoId  popData2020 continentExp
# ...

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=8880, step=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  8880 non-null   object
#  1   day                      8880 non-null   int64
#  2   month                    8880 non-null   int64
#  3   year                     8880 non-null   int64
#  4   cases                    8880 non-null   int64
#  5   deaths                   8880 non-null   int64
#  6   countriesAndTerritories  8880 non-null   object
#  7   geoId                    8880 non-null   object
#  8   countryterritoryCode     8880 non-null   object
#  9   popData2020              8880 non-null   int64
#  10  continentExp             8880 non-null   object
# dtypes: int64(6), object(5)
# memory usage: 763.2+ KB

# %%
dataset.count()
# Out:
# dateRep                    8880
# day                        8880
# month                      8880
# year                       8880
# cases                      8880
# deaths                     8880
# countriesAndTerritories    8880
# geoId                      8880
# countryterritoryCode       8880
# popData2020                8880
# continentExp               8880
# dtype: int64

# %%
dataset.describe()
# Out:
#                day        month    year         cases        deaths  \
# count  8880.000000  8880.000000  8880.0  8.880000e+03   8880.000000
# mean     15.443356     7.346847  2021.0  5.850990e+03     99.705856
# std       8.743685     2.799404     0.0  7.259929e+04   1875.713706
# min       1.000000     2.000000  2021.0 -2.001000e+03     -3.000000
# 25%       8.000000     5.000000  2021.0  1.700000e+02      0.000000
# 50%      15.000000     7.000000  2021.0  8.130000e+02      6.000000
# 75%      23.000000    10.000000  2021.0  3.085000e+03     34.000000
# max      31.000000    12.000000  2021.0  3.645305e+06  97699.000000
#
#         popData2020
# count  8.880000e+03
# mean   1.510301e+07
# std    2.121567e+07
# min    3.874700e+04
# 25%    2.095861e+06
# 50%    6.387122e+06
# 75%    1.152244e+07
# max    8.316671e+07

# %%
dataset.min()
# Out:
# dateRep                    01/03/2021
# day                                 1
# month                               2
# year                             2021
# cases                           -2001
# deaths                             -3
# countriesAndTerritories       Austria
# geoId                              AT
# popData2020                     38747
# continentExp                   Europe
# dtype: object

# %%
dataset.min()
# Out:
# dateRep                    01/03/2021
# day                                 1
# month                               2
# year                             2021
# cases                           -2001
# deaths                             -3
# countriesAndTerritories       Austria
# geoId                              AT
# popData2020                     38747
# continentExp                   Europe
# dtype: object

# %%
dataset.max()
# Out:
# dateRep                    31/10/2021
# day                                31
# month                              12
# year                             2021
# cases                         3645305
# deaths                          97699
# countriesAndTerritories        Sweden
# geoId                              SK
# popData2020                  83166711
# continentExp                   Europe
# dtype: object

# %%
dataset['deaths']
# Out:
# 0          20
# 1          13
# 2          17
# 3          51
# 4          35
#         ...
# 8875       18
# 8876       23
# 8877       24
# 8878       25
# 8879    13031
# Name: deaths, Length: 8880, dtype: int64

# %%
dataset['deaths'].value_counts()[0:5]
# Out:
# 0    2317
# 1     652
# 2     511
# 3     355
# 4     277
# Name: deaths, dtype: int64

# %%
df = dataset.head(100)

# %%
df
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   21/12/2021   21     12  2021   1863      20                 Austria    AT
# 1   20/12/2021   20     12  2021   2131      13                 Austria    AT
# 2   19/12/2021   19     12  2021   2378      17                 Austria    AT
# 3   18/12/2021   18     12  2021   2577      51                 Austria    AT
# 4   17/12/2021   17     12  2021   2847      35                 Austria    AT
# ..         ...  ...    ...   ...    ...     ...                     ...   ...
# 95  17/09/2021   17      9  2021   2283       8                 Austria    AT
# 96  16/09/2021   16      9  2021   2638       8                 Austria    AT
# 97  15/09/2021   15      9  2021   1859       7                 Austria    AT
# 98  14/09/2021   14      9  2021   1227       4                 Austria    AT
# 99  13/09/2021   13      9  2021   1891       0                 Austria    AT
#
#     popData2020 continentExp
# ...

# %%
df['popData2020']
# Out:
# 0     8901064
# 1     8901064
# 2     8901064
# 3     8901064
# 4     8901064
#        ...
# 95    8901064
# 96    8901064
# 97    8901064
# 98    8901064
# 99    8901064
# Name: popData2020, Length: 100, dtype: int64

# %%
dataset
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     21/12/2021   21     12  2021    1863      20                 Austria
# 1     20/12/2021   20     12  2021    2131      13                 Austria
# 2     19/12/2021   19     12  2021    2378      17                 Austria
# 3     18/12/2021   18     12  2021    2577      51                 Austria
# 4     17/12/2021   17     12  2021    2847      35                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 8875  05/03/2021    5      3  2021    4882      18                  Sweden
# 8876  04/03/2021    4      3  2021    4873      23                  Sweden
# 8877  03/03/2021    3      3  2021    6190      24                  Sweden
# 8878  02/03/2021    2      3  2021    2828      25                  Sweden
# 8879  01/03/2021    1      3  2021  666139   13031                  Sweden
#
#      geoId  popData2020 continentExp
# ...

# %%
dataset['deaths'].sum()
# Out:
# 885388

# %%
dataset['day'].sum()
# Out:
# 137137

# %%
dataset['cases'].sum()
# Out:
# 51956793

# %%
dataset['cases'].sum()- dataset['deaths'].sum()
# Out:
# 51071405

# %%
dataset.duplicated(['countriesAndTerritories']).sum()
# Out:
# 8850

# %%
dataset['countriesAndTerritories'].nunique()
# Out:
# 30

# %%
dataset['continentExp'].nunique()
# Out:
# 1

# %%
dataset['year'].nunique()
# Out:
# 1

# %%
from collections import Counter

# %%
dataset['countriesAndTerritories']
# Out:
# 0       Austria
# 1       Austria
# 2       Austria
# 3       Austria
# 4       Austria
#          ...
# 8875     Sweden
# 8876     Sweden
# 8877     Sweden
# 8878     Sweden
# 8879     Sweden
# Name: countriesAndTerritories, Length: 8880, dtype: object

# %%
Counter(dataset['countriesAndTerritories'])
# Out:
# Counter({'Austria': 296,
#          'Belgium': 296,
#          'Bulgaria': 296,
#          'Croatia': 296,
#          'Cyprus': 296,
#          'Czechia': 296,
#          'Denmark': 296,
#          'Estonia': 296,
#          'Finland': 296,
#          'France': 296,
#          'Germany': 296,
#          'Greece': 296,
#          'Hungary': 296,
#          'Iceland': 296,
#          'Ireland': 296,
#          'Italy': 296,
#          'Latvia': 296,
#          'Liechtenstein': 296,
#          'Lithuania': 296,
#          'Luxembourg': 296,
#          'Malta': 296,
#          'Netherlands': 296,
#          'Norway': 296,
#          'Poland': 296,
#          'Portugal': 296,
#          'Romania': 296,
#          'Slovakia': 296,
#          'Slovenia': 296,
#          'Spain': 296,
#          'Sweden': 296})

# %%
dataset['countriesAndTerritories'].value_counts()
# Out:
# Austria          296
# Belgium          296
# Spain            296
# Slovenia         296
# Slovakia         296
# Romania          296
# Portugal         296
# Poland           296
# Norway           296
# Netherlands      296
# Malta            296
# Luxembourg       296
# Lithuania        296
# Liechtenstein    296
# Latvia           296
# Italy            296
# Ireland          296
# Iceland          296
# Hungary          296
# Greece           296
# Germany          296
# France           296
# Finland          296
# Estonia          296
# Denmark          296
# Czechia          296
# Cyprus           296
# Croatia          296
# Bulgaria         296
# Sweden           296
# Name: countriesAndTerritories, dtype: int64

# %%
gc = dataset['countriesAndTerritories'].value_counts()

# %%
gc.plot()

# %%
gc.plot(kind='bar')

# %%
gc.plot(kind='pie')

# %%
dataset['deaths'].plot()

# %%
dataset.plot()

# %%
# subplot
#plt.subplot(#Total num of rows ,total num of columns,plot num)
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot('deaths' , hue = 'countriesAndTerritories' , data = dataset)
# Out:
# /home/tabish/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lineplot(x='day',y='deaths', data= dataset, hue = 'cases')
plt.show()

# %%
dataset['day']
# Out:
# 0       21
# 1       20
# 2       19
# 3       18
# 4       17
#         ..
# 8875     5
# 8876     4
# 8877     3
# 8878     2
# 8879     1
# Name: day, Length: 8880, dtype: int64

# %%
dataset.set_index('day') #x-axis
fig = plt.figure()
x1 = fig.add_subplot(111)
dataset['deaths'].plot(ax=x1 ,label='deaths')
plt.xlabel('day')
x1.set_ylabel('deaths')
plt.legend(loc=1)

x2= x1.twinx()
dataset['cases'].plot(ax=x2 , label='cases', color='green')
x2.set_ylabel('cases')
plt.legend(loc=2)
plt.show()
